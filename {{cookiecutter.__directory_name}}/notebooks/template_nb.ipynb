# %% [raw]
# ---
# title: "Untitled"
# format: html
# ---

# %%
# imports
from pathlib import Path

# third-party
import polars as pl
import polars.selectors as cs
from great_tables import GT, md, html, loc, style
import gt_extras as gte

# %%
file_path = Path(r"")
file_name = Path("")

#df = pl.read_csv(file_path / file_name)

df = pl.read_parquet(file_path / file_name)
